# %%
# %run ./Tools

# %%
guid = dbutils.widgets.get("guid")

# %%
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
}
url = "https://rickandmortyapi.com/api"
guid = str(uuid4())
ingestion_timestamp = datetime.now()

saveToTable(url, 'episode', headers, guid, ingestion_timestamp)
saveToTable(url, 'character', headers, guid, ingestion_timestamp)
saveToTable(url, 'location', headers, guid, ingestion_timestamp)
